# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhilongo/yolo/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.1/910.1 kB 24.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="qr6F09bTiyZpzl9weWYc")
project = rf.workspace("roboflow-58fyf").project("rock-paper-scissors-sxsw")
version = project.version(14)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to rock-paper-scissors-14 in yolov11:: 100%|██████████| 14682/14682 [00:03<00:00, 3831.95it/s]

# %%
from ultralytics import YOLO as yolo
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = yolo("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 111MB/s]

# %%
train_results = model.train(
    data="/content/rock-paper-scissors-14/data.yaml",  # path to dataset YAML
    epochs=1,  # number of training epochs
    imgsz=640,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Ultralytics 8.3.62 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
result = model('/content/rock-paper-scissors-14/test/images/20220216_221550_jpg.rf.02a071a383151953fcf8671fc7fca3af.jpg')
# Out:
# image 1/1 /content/rock-paper-scissors-14/test/images/20220216_221550_jpg.rf.02a071a383151953fcf8671fc7fca3af.jpg: 640x640 2 Scissorss, 19.3ms
# Speed: 3.1ms preprocess, 19.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
result[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
from IPython.display import Image

# %%
Image('/content/runs/detect/train/confusion_matrix.png',width=600)

# %%
Image("/content/runs/detect/train/labels.jpg", width=600)

# %%
Image("/content/runs/detect/train/results.png", width=600)
